# %% [markdown]
# # LGM Data Science Internship Programme
# ## Beginner Level Task-4
# ## Name of Project : Image to Pencil Sketch with Python

# %%
import cv2
import numpy as np
from PIL import Image
from IPython.display import display

# %%
image = cv2.imread("xyz.jpg")

# %%
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
display(Image.fromarray(image))
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x1C353463A30>

# %%
grayImg = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(grayImg))
# Out:
# <PIL.Image.Image image mode=L size=1280x720 at 0x1C354CFA130>

# %%
inv_grayImg = 255 - grayImg

# %%
inv_grayImg
# Out:
# array([[  8,   8,   8, ...,   0,   0,   0],
#        [  8,   8,   8, ...,   0,   0,   0],
#        [  8,   8,   8, ...,   0,   0,   0],
#        ...,
#        [ 39,  39,  39, ..., 108, 108, 108],
#        [ 38,  38,  38, ..., 108, 108, 108],
#        [ 38,  38,  38, ..., 108, 108, 108]], dtype=uint8)

# %%
display(Image.fromarray(inv_grayImg))
# Out:
# <PIL.Image.Image image mode=L size=1280x720 at 0x1C3553FE910>

# %%
blur_img = cv2.GaussianBlur(inv_grayImg, (35,35), 0)

# %%
display(Image.fromarray(blur_img))
# Out:
# <PIL.Image.Image image mode=L size=1280x720 at 0x1C3553FE910>

# %%
inv_blurImg = 255 - blur_img

# %%
inv_blurImg
# Out:
# array([[247, 247, 247, ..., 255, 255, 255],
#        [247, 247, 247, ..., 255, 255, 255],
#        [247, 247, 247, ..., 255, 255, 255],
#        ...,
#        [214, 214, 214, ..., 147, 147, 147],
#        [214, 214, 214, ..., 147, 147, 147],
#        [214, 214, 214, ..., 147, 147, 147]], dtype=uint8)

# %%
display(Image.fromarray(inv_blurImg))
# Out:
# <PIL.Image.Image image mode=L size=1280x720 at 0x1C3553FE5B0>

# %%
def mix(grayImg, blur_img):
    return cv2.divide(grayImg, inv_blurImg, scale = 210.0)

# %%
pencil_sketch = mix(grayImg, inv_blurImg)
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=L size=1280x720 at 0x1C3553FED90>
